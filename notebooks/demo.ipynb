# %% [markdown]
# <a href="https://colab.research.google.com/github/fabiodr/colabs/blob/main/notebooks/demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import subprocess
import sys

process = subprocess.Popen(
  [
    "uvx",
    "--refresh",
    "--from",
    "mjlab==0.1.0",
    "--with",
    "mujoco-warp @ git+https://github.com/google-deepmind/mujoco_warp@486642c3fa262a989b482e0e506716d5793d61a9",
    "demo",
  ],
  stdout=subprocess.PIPE,
  stderr=subprocess.STDOUT,
  universal_newlines=True,
  bufsize=1,
)

for line in process.stdout:
  print(line, end="")
  sys.stdout.flush()

  if "serving" in line.lower() or "running on" in line.lower() or "8081" in line:
    print("\n" + "=" * 50)
    print("✅ Server is running! Execute the next cell to view.")
    print("=" * 50)
    break

# %%
from google.colab import output

output.serve_kernel_port_as_iframe(8081)
